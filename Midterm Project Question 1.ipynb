# %%
import matplotlib.pyplot as plt
import numpy as np

with open('numbers.txt') as f:
    lines = f.read().splitlines()
    new_line = ','.join(lines)
    
my_list = new_line.split(",")

dict = {}
        
for i in my_list:
    if i in dict:  
        dict[i] += 1
    else:
        dict[i] = 1  

list=sorted(dict.items())
for i in list:
    print(i[0],":",i[1])
    
numbers = np.array([2,4,6,8,4,5,2,1,9,0,4,6,7,4,3,2,1,9,10,3,7,9,6,0,1,3,5,6,7,8,9,10,2,3,6,8,9,10,6,7,4,3,
2,1,9,10,3,7,9,6,0,1,3,5,6,7,8,9,10,2,3,6,8,9,10,2,4,6,8,4,5,2,1,9,0,4,6,7,4,3,2,1,9,10,3,7,9,6,
4,5,2,1,9,0,4,6,7,4,3,2,1,9,10,3,7,9,6,0,1,3,5,6,7,8,9,10,2,3,6,8,9,10,6,7,4,3,6,8,4,5,2,
10,3,7,9,6,0,1,3,5,6,7,8,9,10,2,3,6,8,9,10,2,4,6,8,4,5,2,1,9,0,4,6,7,4,
2,4,6,8,4,5,2,1,9,0,4,6,7,4,3,2,1,9,10,3,7,9,6])

mu, sigma = numbers.mean(), numbers.std()
s = np.random.normal(mu,sigma, 1000)
plt.hist(s)
plt.show()
# Out:
# 0 : 9
# 1 : 14
# 10 : 14
# 2 : 19
# 3 : 20
# 4 : 22
# 5 : 10
# 6 : 26
# 7 : 17
# 8 : 13
# 9 : 24

# %%
import json
with open("midterm.json", "w") as outfile:
    json.dump(dict, outfile)
